# %% [markdown]
# PANDAS PROJECT
# NAME: ELIMELECH
# ROLL NO: SU-92-BSAIM-F24-009
# PROGRAM: BS-A1(1st SEMESTER)

# %% [markdown]
# 1) DATA LOADING
#   .You can load data in csv,excel,json,etc.

# %%
import pandas as pd
df =pd.read_csv("data.csv")

# %%
df
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.head()
# Out:
#    Year     Austria       Belgium       Denmark       Finland        France  \
# 0  1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1  1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2  1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3  1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4  1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
#
#         Germany        Greece      Iceland       Ireland         Italy  \
# 0  8.431095e+10  4.335192e+09  252169712.0  1.998550e+09  4.191581e+10
# 1  9.620573e+10  4.961399e+09  257703244.6  2.151773e+09  4.654222e+10
# 2  1.055090e+11  5.213043e+09  289200704.4  2.329373e+09  5.229335e+10
# 3  1.118230e+11  5.895281e+09  345175036.1  2.505073e+09  5.989787e+10
# 4  1.228800e+11  6.669670e+09  440797869.3  2.851092e+09  6.556965e+10
#
#     Luxembourg   Netherlands        Norway      Portugal         Spain  \
# ...

# %%
df.tail()
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
#          Germany        Greece       Iceland       Ireland         Italy  \
# 59  3.889180e+12  2.052530e+11  2.468134e+10  3.989330e+11  2.011300e+12
# 60  3.887730e+12  1.884800e+11  2.162995e+10  4.286090e+11  1.897460e+12
# 61  4.278500e+12  2.146680e+11  2.579787e+10  5.133920e+11  2.154880e+12
# 62  4.082470e+12  2.175810e+11  2.870183e+10  5.331400e+11  2.066970e+12
# 63  4.456080e+12  2.382060e+11  3.102003e+10  5.456290e+11  2.254850e+12
#
# ...

# %%
df.describe()
# Out:
#               Year       Austria       Belgium       Denmark       Finland  \
# count    64.000000  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01
# mean   1991.500000 -2.147484e+09  2.428867e+11  1.617270e+11  1.253740e+11
# std      18.618987  0.000000e+00  1.973177e+11  1.317595e+11  1.014321e+11
# min    1960.000000 -2.147484e+09  1.181062e+10  6.361166e+09  5.279011e+09
# 25%    1975.750000 -2.147484e+09  6.975496e+10  4.355052e+10  3.125529e+10
# 50%    1991.500000 -2.147484e+09  2.176165e+11  1.412105e+11  1.157725e+11
# 75%    2007.250000 -2.147484e+09  4.644825e+11  3.052838e+11  2.360932e+11
# max    2023.000000 -2.147484e+09  6.322170e+11  4.056880e+11  3.001870e+11
#
#              France       Germany        Greece       Iceland       Ireland  \
# count  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01
# mean   1.332031e+12  1.857701e+12  1.212345e+11  8.909102e+09  1.236252e+11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            64 non-null     int64
#  1   Austria         64 non-null     int64
#  2   Belgium         64 non-null     float64
#  3   Denmark         64 non-null     float64
#  4   Finland         64 non-null     float64
#  5   France          64 non-null     float64
#  6   Germany         64 non-null     float64
#  7   Greece          64 non-null     float64
#  8   Iceland         64 non-null     float64
#  9   Ireland         64 non-null     float64
#  10  Italy           64 non-null     float64
#  11  Luxembourg      64 non-null     float64
#  12  Netherlands     64 non-null     float64
#  13  Norway          64 non-null     float64
#  14  Portugal        64 non-null     float64
#  15  Spain           64 non-null     float64
#  16  Sweden          64 non-null     float64
# ...

# %%
df.max()
# Out:
# Year              2.023000e+03
# Austria          -2.147484e+09
# Belgium           6.322170e+11
# Denmark           4.056880e+11
# Finland           3.001870e+11
# France            3.030900e+12
# Germany           4.456080e+12
# Greece            3.559090e+11
# Iceland           3.102003e+10
# Ireland           5.456290e+11
# Italy             2.408660e+12
# Luxembourg        8.575501e+10
# Netherlands       1.118120e+12
# Norway            5.937270e+11
# Portugal          2.870800e+11
# Spain             1.631860e+12
# Sweden            6.397150e+11
# Switzerland       8.849400e+11
# United Kingdom    3.340030e+12
# dtype: float64

# %%
df.min()
# Out:
# Year              1.960000e+03
# Austria          -2.147484e+09
# Belgium           1.181062e+10
# Denmark           6.361166e+09
# Finland           5.279011e+09
# France            6.222548e+10
# Germany           8.431095e+10
# Greece            4.335192e+09
# Iceland           2.521697e+08
# Ireland           1.998550e+09
# Italy             4.191581e+10
# Luxembourg        7.099419e+08
# Netherlands       1.326346e+10
# Norway            5.197399e+09
# Portugal          3.339150e+09
# Spain             1.243339e+10
# Sweden            1.595320e+10
# Switzerland       1.041223e+10
# United Kingdom    7.323397e+10
# dtype: float64

# %%
df.sum()
# Out:
# Year              1.274560e+05
# Austria          -1.374390e+11
# Belgium           1.554475e+13
# Denmark           1.035053e+13
# Finland           8.023937e+12
# France            8.524996e+13
# Germany           1.188929e+14
# Greece            7.759009e+12
# Iceland           5.701826e+11
# Ireland           7.912010e+12
# Italy             6.754456e+13
# Luxembourg        1.626877e+12
# Netherlands       2.634766e+13
# Norway            1.193521e+13
# Portugal          6.856435e+12
# Spain             3.988299e+13
# Sweden            1.666335e+13
# Switzerland       1.955969e+13
# United Kingdom    8.610475e+13
# dtype: float64

# %%
df.mean()
# Out:
# Year              1.991500e+03
# Austria          -2.147484e+09
# Belgium           2.428867e+11
# Denmark           1.617270e+11
# Finland           1.253740e+11
# France            1.332031e+12
# Germany           1.857701e+12
# Greece            1.212345e+11
# Iceland           8.909102e+09
# Ireland           1.236252e+11
# Italy             1.055384e+12
# Luxembourg        2.541995e+10
# Netherlands       4.116823e+11
# Norway            1.864876e+11
# Portugal          1.071318e+11
# Spain             6.231717e+11
# Sweden            2.603648e+11
# Switzerland       3.056201e+11
# United Kingdom    1.345387e+12
# dtype: float64

# %%
df["Austria"]
# Out:
# 0    -2147483648
# 1    -2147483648
# 2    -2147483648
# 3    -2147483648
# 4    -2147483648
#          ...
# 59   -2147483648
# 60   -2147483648
# 61   -2147483648
# 62   -2147483648
# 63   -2147483648
# Name: Austria, Length: 64, dtype: int64

# %%
type(df["Austria"])
# Out:
# pandas.core.series.Series

# %%
df[["Year", "Austria"]]
# Out:
#     Year     Austria
# 0   1960 -2147483648
# 1   1961 -2147483648
# 2   1962 -2147483648
# 3   1963 -2147483648
# 4   1964 -2147483648
# ..   ...         ...
# 59  2019 -2147483648
# 60  2020 -2147483648
# 61  2021 -2147483648
# 62  2022 -2147483648
# 63  2023 -2147483648
#
# [64 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Year              1.960000e+03
# Austria          -2.147484e+09
# Belgium           1.181062e+10
# Denmark           6.361166e+09
# Finland           5.279011e+09
# France            6.222548e+10
# Germany           8.431095e+10
# Greece            4.335192e+09
# Iceland           2.521697e+08
# Ireland           1.998550e+09
# Italy             4.191581e+10
# Luxembourg        7.099419e+08
# Netherlands       1.326346e+10
# Norway            5.197399e+09
# Portugal          3.339150e+09
# Spain             1.243339e+10
# Sweden            1.595320e+10
# Switzerland       1.041223e+10
# United Kingdom    7.323397e+10
# Name: 0, dtype: float64

# %%
df.notnull()
# Out:
#     Year  Austria  Belgium  Denmark  Finland  France  Germany  Greece  \
# 0   True     True     True     True     True    True     True    True
# 1   True     True     True     True     True    True     True    True
# 2   True     True     True     True     True    True     True    True
# 3   True     True     True     True     True    True     True    True
# 4   True     True     True     True     True    True     True    True
# ..   ...      ...      ...      ...      ...     ...      ...     ...
# 59  True     True     True     True     True    True     True    True
# 60  True     True     True     True     True    True     True    True
# 61  True     True     True     True     True    True     True    True
# 62  True     True     True     True     True    True     True    True
# 63  True     True     True     True     True    True     True    True
#
#     Iceland  Ireland  Italy  Luxembourg  Netherlands  Norway  Portugal  Spain  \
# ...

# %%
df.notnull().sum()
# Out:
# Year              64
# Austria           64
# Belgium           64
# Denmark           64
# Finland           64
# France            64
# Germany           64
# Greece            64
# Iceland           64
# Ireland           64
# Italy             64
# Luxembourg        64
# Netherlands       64
# Norway            64
# Portugal          64
# Spain             64
# Sweden            64
# Switzerland       64
# United Kingdom    64
# dtype: int64

# %%
df.isnull()
# Out:
#      Year  Austria  Belgium  Denmark  Finland  France  Germany  Greece  \
# 0   False    False    False    False    False   False    False   False
# 1   False    False    False    False    False   False    False   False
# 2   False    False    False    False    False   False    False   False
# 3   False    False    False    False    False   False    False   False
# 4   False    False    False    False    False   False    False   False
# ..    ...      ...      ...      ...      ...     ...      ...     ...
# 59  False    False    False    False    False   False    False   False
# 60  False    False    False    False    False   False    False   False
# 61  False    False    False    False    False   False    False   False
# 62  False    False    False    False    False   False    False   False
# 63  False    False    False    False    False   False    False   False
#
#     Iceland  Ireland  Italy  Luxembourg  Netherlands  Norway  Portugal  Spain  \
# ...

# %%
df.isnull().sum()
# Out:
# Year              0
# Austria           0
# Belgium           0
# Denmark           0
# Finland           0
# France            0
# Germany           0
# Greece            0
# Iceland           0
# Ireland           0
# Italy             0
# Luxembourg        0
# Netherlands       0
# Norway            0
# Portugal          0
# Spain             0
# Sweden            0
# Switzerland       0
# United Kingdom    0
# dtype: int64

# %%
df.dropna()
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.dropna(axis=1)
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.fillna(0)
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.interpolate()
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# Length: 64, dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.rename(columns={"Austria": "At"})
# Out:
#     Year          At       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            64 non-null     int64
#  1   Austria         64 non-null     int64
#  2   Belgium         64 non-null     float64
#  3   Denmark         64 non-null     float64
#  4   Finland         64 non-null     float64
#  5   France          64 non-null     float64
#  6   Germany         64 non-null     float64
#  7   Greece          64 non-null     float64
#  8   Iceland         64 non-null     float64
#  9   Ireland         64 non-null     float64
#  10  Italy           64 non-null     float64
#  11  Luxembourg      64 non-null     float64
#  12  Netherlands     64 non-null     float64
#  13  Norway          64 non-null     float64
#  14  Portugal        64 non-null     float64
#  15  Spain           64 non-null     float64
#  16  Sweden          64 non-null     float64
# ...

# %%
df['Austria'] = df['Austria'].astype("string")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            64 non-null     int64
#  1   Austria         64 non-null     string
#  2   Belgium         64 non-null     float64
#  3   Denmark         64 non-null     float64
#  4   Finland         64 non-null     float64
#  5   France          64 non-null     float64
#  6   Germany         64 non-null     float64
#  7   Greece          64 non-null     float64
#  8   Iceland         64 non-null     float64
#  9   Ireland         64 non-null     float64
#  10  Italy           64 non-null     float64
#  11  Luxembourg      64 non-null     float64
#  12  Netherlands     64 non-null     float64
#  13  Norway          64 non-null     float64
#  14  Portugal        64 non-null     float64
#  15  Spain           64 non-null     float64
#  16  Sweden          64 non-null     float64
# ...

# %%
df
# Out:
#     Year        Austria       Belgium       Denmark       Finland  \
# 0   1960  -2147483648.0  1.181062e+10  6.361166e+09  5.279011e+09
# 1   1961  -2147483648.0  1.256170e+10  7.058361e+09  5.983900e+09
# 2   1962  -2147483648.0  1.343683e+10  7.953274e+09  6.407225e+09
# 3   1963  -2147483648.0  1.444581e+10  8.466045e+09  6.958296e+09
# 4   1964  -2147483648.0  1.616804e+10  9.677401e+09  7.848288e+09
# ..   ...            ...           ...           ...           ...
# 59  2019  -2147483648.0  5.358660e+11  3.464990e+11  2.685150e+11
# 60  2020  -2147483648.0  5.260220e+11  3.547630e+11  2.718860e+11
# 61  2021  -2147483648.0  6.009040e+11  4.056880e+11  2.964700e+11
# 62  2022  -2147483648.0  5.836140e+11  4.001670e+11  2.818870e+11
# 63  2023  -2147483648.0  6.322170e+11  4.041990e+11  3.001870e+11
#
#           France       Germany        Greece       Iceland       Ireland  \
# 0   6.222548e+10  8.431095e+10  4.335192e+09  2.521697e+08  1.998550e+09
# ...

# %%
df['Austria'][0]
# Out:
# '-2147483648.0'

# %%
len(df)
# Out:
# 64

# %%
df["Lahore"] = [5 for i in range(len(df))]

# %%
df
# Out:
#     Year        Austria       Belgium       Denmark       Finland  \
# 0   1960  -2147483648.0  1.181062e+10  6.361166e+09  5.279011e+09
# 1   1961  -2147483648.0  1.256170e+10  7.058361e+09  5.983900e+09
# 2   1962  -2147483648.0  1.343683e+10  7.953274e+09  6.407225e+09
# 3   1963  -2147483648.0  1.444581e+10  8.466045e+09  6.958296e+09
# 4   1964  -2147483648.0  1.616804e+10  9.677401e+09  7.848288e+09
# ..   ...            ...           ...           ...           ...
# 59  2019  -2147483648.0  5.358660e+11  3.464990e+11  2.685150e+11
# 60  2020  -2147483648.0  5.260220e+11  3.547630e+11  2.718860e+11
# 61  2021  -2147483648.0  6.009040e+11  4.056880e+11  2.964700e+11
# 62  2022  -2147483648.0  5.836140e+11  4.001670e+11  2.818870e+11
# 63  2023  -2147483648.0  6.322170e+11  4.041990e+11  3.001870e+11
#
#           France       Germany        Greece       Iceland       Ireland  \
# 0   6.222548e+10  8.431095e+10  4.335192e+09  2.521697e+08  1.998550e+09
# ...

# %%
def fx(a):
  return a*a
df["Sheikhupura"] = df["Lahore"].apply(fx)

# %%
df
# Out:
#     Year        Austria       Belgium       Denmark       Finland  \
# 0   1960  -2147483648.0  1.181062e+10  6.361166e+09  5.279011e+09
# 1   1961  -2147483648.0  1.256170e+10  7.058361e+09  5.983900e+09
# 2   1962  -2147483648.0  1.343683e+10  7.953274e+09  6.407225e+09
# 3   1963  -2147483648.0  1.444581e+10  8.466045e+09  6.958296e+09
# 4   1964  -2147483648.0  1.616804e+10  9.677401e+09  7.848288e+09
# ..   ...            ...           ...           ...           ...
# 59  2019  -2147483648.0  5.358660e+11  3.464990e+11  2.685150e+11
# 60  2020  -2147483648.0  5.260220e+11  3.547630e+11  2.718860e+11
# 61  2021  -2147483648.0  6.009040e+11  4.056880e+11  2.964700e+11
# 62  2022  -2147483648.0  5.836140e+11  4.001670e+11  2.818870e+11
# 63  2023  -2147483648.0  6.322170e+11  4.041990e+11  3.001870e+11
#
#           France       Germany        Greece       Iceland       Ireland  ...  \
# 0   6.222548e+10  8.431095e+10  4.335192e+09  2.521697e+08  1.998550e+09  ...
# ...

# %%
df.to_csv("export.csv", index=False)

# %%
df1 = pd.DataFrame({
    "name": ["Elimelech", "Muneeb", "Tahir", "Zeeshan", "Happy"],
    "marks": ["10", "9", "8", "7", "6"]})

# %%
df1
# Out:
#         name marks
# 0  Elimelech    10
# 1     Muneeb     9
# 2      Tahir     8
# 3    Zeeshan     7
# 4      Happy     6

# %%
df2 = pd.DataFrame({
    "name": ["Lorem", "Ipsum", "Shahi"],
    "marks": ["10", "9", "8"]})

# %%
df2
# Out:
#     name marks
# 0  Lorem    10
# 1  Ipsum     9
# 2  Shahi     8

# %%
pd.concat([df1,df2])
# Out:
#         name marks
# 0  Elimelech    10
# 1     Muneeb     9
# 2      Tahir     8
# 3    Zeeshan     7
# 4      Happy     6
# 0      Lorem    10
# 1      Ipsum     9
# 2      Shahi     8

# %%
df1 = pd.DataFrame({
    "name":["Danish", "Talha"],
    "marks":["10", "9"]
    
})

# %%
df2 = pd.DataFrame({
    "name":["Danish","Talha"],
    "roll no":["23", "24"]
})

# %%
pd.merge(df1, df2, on= "name")
# Out:
#      name marks roll no
# 0  Danish    10      23
# 1   Talha     9      24

# %% [markdown]
# FOR PLOTTING DIFFERENT TYPE OF GRAPHS IN PANDAS

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#     Year     Austria       Belgium       Denmark       Finland        France  \
# 0   1960 -2147483648  1.181062e+10  6.361166e+09  5.279011e+09  6.222548e+10
# 1   1961 -2147483648  1.256170e+10  7.058361e+09  5.983900e+09  6.746164e+10
# 2   1962 -2147483648  1.343683e+10  7.953274e+09  6.407225e+09  7.560753e+10
# 3   1963 -2147483648  1.444581e+10  8.466045e+09  6.958296e+09  8.475920e+10
# 4   1964 -2147483648  1.616804e+10  9.677401e+09  7.848288e+09  9.400785e+10
# ..   ...         ...           ...           ...           ...           ...
# 59  2019 -2147483648  5.358660e+11  3.464990e+11  2.685150e+11  2.728870e+12
# 60  2020 -2147483648  5.260220e+11  3.547630e+11  2.718860e+11  2.647420e+12
# 61  2021 -2147483648  6.009040e+11  4.056880e+11  2.964700e+11  2.959360e+12
# 62  2022 -2147483648  5.836140e+11  4.001670e+11  2.818870e+11  2.779090e+12
# 63  2023 -2147483648  6.322170e+11  4.041990e+11  3.001870e+11  3.030900e+12
#
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = "bar")
# Out:
# <Axes: >

# %%
df.plot(kind ="box")
# Out:
# <Axes: >

# %%
df.plot(x = "Year", y = "Sweden")
# Out:
# <Axes: xlabel='Year'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "bar")
# Out:
# <Axes: xlabel='Year'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "barh")
# Out:
# <Axes: ylabel='Year'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "box")
# Out:
# <Axes: >

# %%
df.plot(x = "Year", y = "Sweden", kind = "area")
# Out:
# <Axes: xlabel='Year'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "pie")
# Out:
# <Axes: ylabel='Sweden'>

# %%
df.plot(x = "Year", y = "Sweden", kind = "scatter")
# Out:
# <Axes: xlabel='Year', ylabel='Sweden'>
